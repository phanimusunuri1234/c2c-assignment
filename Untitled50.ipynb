# %% [markdown]
# <a href="https://colab.research.google.com/github/phanimusunuri1234/c2c-assignment/blob/main/Untitled50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
df=pd.read_excel("/content/Airfoilself.xlsx",sheet_name=1)
df
# Out:
#       Frequency (Hz)  Angle of Attack (Degrees)  Chord length (m)  \
# 0                800                        0.0            0.3048
# 1               1000                        0.0            0.3048
# 2               1250                        0.0            0.3048
# 3               1600                        0.0            0.3048
# 4               2000                        0.0            0.3048
# ...              ...                        ...               ...
# 1498            2500                       15.6            0.1016
# 1499            3150                       15.6            0.1016
# 1500            4000                       15.6            0.1016
# 1501            5000                       15.6            0.1016
# 1502            6300                       15.6            0.1016
#
#       Free stream velocity (m/s)  Suction side displacement thickness (m)  \
# 0                           71.3                                 0.002663
# ...

# %%
df.head(5)
# Out:
#    Frequency (Hz)  Angle of Attack (Degrees)  Chord length (m)  \
# 0             800                        0.0            0.3048
# 1            1000                        0.0            0.3048
# 2            1250                        0.0            0.3048
# 3            1600                        0.0            0.3048
# 4            2000                        0.0            0.3048
#
#    Free stream velocity (m/s)  Suction side displacement thickness (m)  \
# 0                        71.3                                 0.002663
# 1                        71.3                                 0.002663
# 2                        71.3                                 0.002663
# 3                        71.3                                 0.002663
# 4                        71.3                                 0.002663
#
#    Scaled sound pressure level (Decibels)
# 0                                 126.201
# 1                                 125.201
# ...

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
x=df.iloc[:,0:5]
y=df.iloc[:,5]

lr = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=1)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# 133.09330984164674
# [-1.27602910e-03 -4.08079464e-01 -3.61173791e+01  9.87437412e-02
#  -1.61990153e+02]

# %%
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 4.96365737855477

# %%
{i:j for i,j in zip(df.columns,lr.coef_)}
# Out:
# {'Angle of Attack (Degrees)': -0.40807946408172924,
#  'Chord length (m)': -36.11737913456952,
#  'Free stream velocity (m/s)': 0.09874374118953955,
#  'Frequency (Hz)': -0.001276029096059718,
#  'Suction side displacement thickness (m)': -161.99015325862007}

# %% [markdown]
# <a href="https://colab.research.google.com/github/phanimusunuri1234/c2c-assignment/blob/main/fitness.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df=pd.read_csv("/content/Fitness_tracker_data.csv")
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   12-04-2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   08-05-2016       10686       8.110000         8.110000
# 936  8877689391   09-05-2016       20226      18.250000        18.250000
# 937  8877689391   10-05-2016       10733       8.150000         8.150000
# 938  8877689391   11-05-2016       21420      19.559999        19.559999
# 939  8877689391   12-05-2016        8064       6.120000         6.120000
#
#      Unnamed: 5  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df['ActivityDate'].unique()
# Out:
# array(['12-04-2016', '4/13/2016', '4/14/2016', '4/15/2016', '4/16/2016',
#        '4/17/2016', '4/18/2016', '4/19/2016', '4/20/2016', '4/21/2016',
#        '4/22/2016', '4/23/2016', '4/24/2016', '4/25/2016', '4/26/2016',
#        '4/27/2016', '4/28/2016', '4/29/2016', '4/30/2016', '01-05-2016',
#        '02-05-2016', '03-05-2016', '04-05-2016', '05-05-2016',
#        '06-05-2016', '07-05-2016', '08-05-2016', '09-05-2016',
#        '10-05-2016', '11-05-2016', '12-05-2016'], dtype=object)

# %%
df=df.dropna(axis=1)
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   12-04-2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   08-05-2016       10686       8.110000         8.110000
# 936  8877689391   09-05-2016       20226      18.250000        18.250000
# 937  8877689391   10-05-2016       10733       8.150000         8.150000
# 938  8877689391   11-05-2016       21420      19.559999        19.559999
# 939  8877689391   12-05-2016        8064       6.120000         6.120000
#
#      VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# ...

# %%
df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# count          940.000000                940.000000           940.000000
# mean             1.502681                  0.567543             3.340819
# std              2.658941                  0.883580             2.040655
# min              0.000000                  0.000000             0.000000
# ...

# %%
df['ActivityDate']=pd.to_datetime(df['ActivityDate'])
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-12-04       13162       8.500000         8.500000
# 1    1503960366   2016-04-13       10735       6.970000         6.970000
# 2    1503960366   2016-04-14       10460       6.740000         6.740000
# 3    1503960366   2016-04-15        9762       6.280000         6.280000
# 4    1503960366   2016-04-16       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# ...

# %%
df.drop(0,axis=0)
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 1    1503960366   2016-04-13       10735       6.970000         6.970000
# 2    1503960366   2016-04-14       10460       6.740000         6.740000
# 3    1503960366   2016-04-15        9762       6.280000         6.280000
# 4    1503960366   2016-04-16       12669       8.160000         8.160000
# 5    1503960366   2016-04-17        9705       6.480000         6.480000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   2016-08-05       10686       8.110000         8.110000
# 936  8877689391   2016-09-05       20226      18.250000        18.250000
# 937  8877689391   2016-10-05       10733       8.150000         8.150000
# 938  8877689391   2016-11-05       21420      19.559999        19.559999
# 939  8877689391   2016-12-05        8064       6.120000         6.120000
#
#      VeryActiveDistance  ModeratelyActiveDistance  LightActiveDistance  \
# ...

# %%
df['Id'].value_counts().plot(kind='bar', figsize=(10,6));

# %%
df['ActivityDate']=pd.to_datetime(df['ActivityDate'],format='%y%d%m')

# %%
plt.figure(figsize=(33,6))
sns.barplot(df['Id'],df['Calories'])
plt.show()

# %%
plt.figure(figsize=(33,6))
sns.barplot(df['Id'],df['TotalSteps'])
plt.show()

# %%
plt.figure(figsize=(33,6))
sns.barplot(df['ActivityDate'],df['Calories'])
plt.show()

# %%
df['Calories'].plot(figsize=(12,4))

# %%
sns.pairplot(data)

# %% [markdown]
# a=sns.countplot(x='Id',data=df)
# a.set_ylabel('Calories')

# %%
data=df.drop(["Id","ActivityDate"],axis=1)

# %%
cor=data.corr()
cor
# Out:
#                           TotalSteps  TotalDistance  TrackerDistance  \
# TotalSteps                  1.000000       0.985369         0.984822
# TotalDistance               0.985369       1.000000         0.999505
# TrackerDistance             0.984822       0.999505         1.000000
# VeryActiveDistance          0.740115       0.794582         0.794338
# ModeratelyActiveDistance    0.507105       0.470758         0.470277
# LightActiveDistance         0.692208       0.662002         0.661365
# VeryActiveMinutes           0.667079       0.681297         0.680816
# FairlyActiveMinutes         0.498693       0.462899         0.463154
# LightlyActiveMinutes        0.569600       0.516300         0.514713
# SedentaryMinutes           -0.327484      -0.288094        -0.289343
# Calories                    0.591568       0.644962         0.645313
#
#                           VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
plt.subplots(figsize=(16,8))
sns.heatmap(cor,annot=True,cmap='coolwarm')

# %%
x=data.drop("Calories",axis=1)

# %%
y=data["Calories"]

# %%
y.unique()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=1)

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (564, 10)
# (376, 10)
# (564,)
# (376,)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([2963.87113013, 2849.62698   , 1702.71111918, 1634.59421733,
#        3632.04756248, 4508.45887925, 2230.7340367 , 2095.15401906,
#        2424.54633352, 1898.99015763, 2505.2546674 , 1853.74748465,
#        2110.00632502, 2253.87660328, 3355.83869868, 1876.12953413,
#        1629.94003595, 1979.00101209, 2698.84541148, 2315.50009927,
#        5399.18793283, 1626.84895183, 2122.72014337, 1777.08558572,
#        1981.08520965, 1788.96696167, 2370.61360515, 1909.0475457 ,
#        3220.92286198, 2271.72712234, 2445.37091173, 2399.79358799,
#        2404.81403491, 2853.89686731, 3000.62112605, 1804.38852133,
#        2288.32050582, 2452.32504788, 3302.81563782, 1702.71111918,
#        1821.09353863, 3952.49447778, 3125.94415574, 1679.86459047,
#        1702.71111918, 1822.46645803, 2091.24989956, 2845.51103181,
#        1911.26520454, 2452.36603564, 5254.12030017, 2460.40100187,
#        2400.59582463, 2223.81592175, 2820.51200448, 2289.71373396,
# ...

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
r2_score(y_test,y_pred)*100
#r2_score(y1_test,y_pred1)*100
# Out:
# 78.3016259037187

# %%
import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
m=sm.OLS(y_train,x_train)
results=m.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:               Calories   R-squared (uncentered):                   0.966
# Model:                            OLS   Adj. R-squared (uncentered):              0.966
# Method:                 Least Squares   F-statistic:                              1844.
# Date:                Mon, 04 Jul 2022   Prob (F-statistic):                        0.00
# Time:                        14:49:18   Log-Likelihood:                         -4940.8
# No. Observations:                 658   AIC:                                      9902.
# Df Residuals:                     648   BIC:                                      9946.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
print("mean squared error:{}\n".format(mean_squared_error(y_test,y_pred,squared=False)))

# %%
mean_squared_error(y_test,y_pred,squared=True)

# %%
import math

# %%
rmse=math.sqrt((mean_squared_error(y_test,y_pred,squared=True)))

# %%
rmse

# %%
data['Calories'].plot()

# %%
df['ActivityDate'].head(50)

# %%
plt.scatter(x_train, y_train, color = "red")
plt.plot(x_train, lr.predict(x_train), color = "green")
plt.title("Salary vs Experience (Training set)")
plt.xlabel("x_train")
plt.ylabel("y_train")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-622ae0b509fd> in <module>()
# ----> 1 plt.scatter(x_train, y_train, color = "red")
#       2 plt.plot(x_train, lr.predict(x_train), color = "green")
#       3 plt.title("Salary vs Experience (Training set)")
#       4 plt.xlabel("x_train")
#       5 plt.ylabel("y_train")
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
plt.scatter(x_test, y_test, color = "red")
plt.plot(x_train, lr.predict(x_train), color = "green")
plt.title("Salary vs Experience (Testing set)")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(x_test,y_test, color="black")
plt.plot(x_test,y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
plt.scatter(x, y, color = "m",
               marker = "o", s = 30)

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# 1330.166787529863
# [-4.09897883e-01  5.16669219e+02  2.03794186e+02 -3.04009920e+02
#  -2.84740951e+02 -1.31491549e+01  1.80730581e+01  9.03981913e+00
#   2.99653132e-01  2.59294163e-01]

# %%
print(metrics.mean_absolute_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 262.5980166044614
# 110592.047078136
# 332.553825835963

# %%
import numpy as np

# %%
print(lr.intercept_)
print(lr.coef_)

# %%
sns.pairplot(data, x_vars=['TotalSteps','VeryActiveMinutes','TotalDistance'], y_vars='Calories', size=7, aspect=0.7, kind='reg')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df

# %%
y_pred.plot()

# %%
import numpy as np
df

# %%
x2=data.drop(["VeryActiveMinutes","LightActiveDistance","ModeratelyActiveDistance","FairlyActiveMinutes","LightlyActiveMinutes","SedentaryMinutes"],axis=1)

# %%
y2=data["Calories"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x2,y2,test_size=0.3,random_state=1)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
r2_score(y_test,y_pred)*100
# Out:
# 100.0

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-02cd6a61d56e> in <module>()
# ----> 1 df(y_pred).plot()
#
# TypeError: 'DataFrame' object is not callable
